# %%
import pandas as pd

# %%
import seaborn as sns

# %%
penguins = sns.load_dataset("penguins")

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
type(penguins
    )
# Out:
# pandas.core.frame.DataFrame

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
penguins.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
penguins.dtypes
# Out:
# species               object
# island                object
# bill_length_mm       float64
# bill_depth_mm        float64
# flipper_length_mm    float64
# body_mass_g          float64
# sex                   object
# dtype: object

# %%
penguins.shape
# Out:
# (344, 7)

# %%
len(penguins)
# Out:
# 344

# %%
len(penguins.columns)
# Out:
# 7

# %%
speciesColumn = penguins['species']

# %%
speciesColumn
# Out:
# 0      Adelie
# 1      Adelie
# 2      Adelie
# 3      Adelie
# 4      Adelie
#         ...
# 339    Gentoo
# 340    Gentoo
# 341    Gentoo
# 342    Gentoo
# 343    Gentoo
# Name: species, Length: 344, dtype: object

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
pd.Series(["Male", "Female"])
# Out:
# 0      Male
# 1    Female
# dtype: object

# %%
penguins[['island','species']]
# Out:
#         island species
# 0    Torgersen  Adelie
# 1    Torgersen  Adelie
# 2    Torgersen  Adelie
# 3    Torgersen  Adelie
# 4    Torgersen  Adelie
# ..         ...     ...
# 339     Biscoe  Gentoo
# 340     Biscoe  Gentoo
# 341     Biscoe  Gentoo
# 342     Biscoe  Gentoo
# 343     Biscoe  Gentoo
#
# [344 rows x 2 columns]

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
penguins[['body_mass_g']]
# Out:
#      body_mass_g
# 0         3750.0
# 1         3800.0
# 2         3250.0
# 3            NaN
# 4         3450.0
# ..           ...
# 339          NaN
# 340       4850.0
# 341       5750.0
# 342       5200.0
# 343       5400.0
#
# [344 rows x 1 columns]

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
penguins[['species', 'island', 'sex']]
# Out:
#     species     island     sex
# 0    Adelie  Torgersen    Male
# 1    Adelie  Torgersen  Female
# 2    Adelie  Torgersen  Female
# 3    Adelie  Torgersen     NaN
# 4    Adelie  Torgersen  Female
# ..      ...        ...     ...
# 339  Gentoo     Biscoe     NaN
# 340  Gentoo     Biscoe  Female
# 341  Gentoo     Biscoe    Male
# 342  Gentoo     Biscoe  Female
# 343  Gentoo     Biscoe    Male
#
# [344 rows x 3 columns]

# %%
penguins[['species', 'island', 'sex']].head()
# Out:
#   species     island     sex
# 0  Adelie  Torgersen    Male
# 1  Adelie  Torgersen  Female
# 2  Adelie  Torgersen  Female
# 3  Adelie  Torgersen     NaN
# 4  Adelie  Torgersen  Female

# %%
type(penguins[['species', 'island', 'sex']])
# Out:
# pandas.core.frame.DataFrame

# %%
penguins.loc[0:3]
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN

# %%
penguins.loc[20:25]
# Out:
#    species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 20  Adelie  Biscoe            37.8           18.3              174.0
# 21  Adelie  Biscoe            37.7           18.7              180.0
# 22  Adelie  Biscoe            35.9           19.2              189.0
# 23  Adelie  Biscoe            38.2           18.1              185.0
# 24  Adelie  Biscoe            38.8           17.2              180.0
# 25  Adelie  Biscoe            35.3           18.9              187.0
#
#     body_mass_g     sex
# 20       3400.0  Female
# 21       3600.0    Male
# 22       3800.0  Female
# 23       3950.0    Male
# 24       3800.0    Male
# 25       3800.0  Female

# %%
sepalInfo = penguins[['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g']]

# %%
sepalInfo
# Out:
#      bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# 0              39.1           18.7              181.0       3750.0
# 1              39.5           17.4              186.0       3800.0
# 2              40.3           18.0              195.0       3250.0
# 3               NaN            NaN                NaN          NaN
# 4              36.7           19.3              193.0       3450.0
# ..              ...            ...                ...          ...
# 339             NaN            NaN                NaN          NaN
# 340            46.8           14.3              215.0       4850.0
# 341            50.4           15.7              222.0       5750.0
# 342            45.2           14.8              212.0       5200.0
# 343            49.9           16.1              213.0       5400.0
#
# [344 rows x 4 columns]

# %%
sepalInfo.head()
# Out:
#    bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# 0            39.1           18.7              181.0       3750.0
# 1            39.5           17.4              186.0       3800.0
# 2            40.3           18.0              195.0       3250.0
# 3             NaN            NaN                NaN          NaN
# 4            36.7           19.3              193.0       3450.0

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
penguins['island'] == 'Torgersen'
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Name: island, Length: 344, dtype: bool

# %%
torgersenFilter = penguins['island'] == 'Torgersen'

# %%
penguins[torgersenFilter]
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# 6    Adelie  Torgersen            38.9           17.8              181.0
# 7    Adelie  Torgersen            39.2           19.6              195.0
# 8    Adelie  Torgersen            34.1           18.1              193.0
# 9    Adelie  Torgersen            42.0           20.2              190.0
# 10   Adelie  Torgersen            37.8           17.1              186.0
# 11   Adelie  Torgersen            37.8           17.3              180.0
# ...

# %%
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %% [markdown]
# # Univariate analysis

# %%
penguins['island']
# Out:
# 0      Torgersen
# 1      Torgersen
# 2      Torgersen
# 3      Torgersen
# 4      Torgersen
#          ...
# 339       Biscoe
# 340       Biscoe
# 341       Biscoe
# 342       Biscoe
# 343       Biscoe
# Name: island, Length: 344, dtype: object

# %%
penguins['island'].unique()
# Out:
# array(['Torgersen', 'Biscoe', 'Dream'], dtype=object)

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
penguins[torgersenFilter]
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# 6    Adelie  Torgersen            38.9           17.8              181.0
# 7    Adelie  Torgersen            39.2           19.6              195.0
# 8    Adelie  Torgersen            34.1           18.1              193.0
# 9    Adelie  Torgersen            42.0           20.2              190.0
# 10   Adelie  Torgersen            37.8           17.1              186.0
# 11   Adelie  Torgersen            37.8           17.3              180.0
# ...

# %%
penguins['island'].value_counts()
# Out:
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: island, dtype: int64

# %%
penguins['island'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
penguins[torgersenFilter].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
penguins[torgersenFilter].plot(kind='hist', bins = 10)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
penguins['species'].unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %%
penguins['bill_length_mm'].unique()
# Out:
# array([39.1, 39.5, 40.3,  nan, 36.7, 39.3, 38.9, 39.2, 34.1, 42. , 37.8,
#        41.1, 38.6, 34.6, 36.6, 38.7, 42.5, 34.4, 46. , 37.7, 35.9, 38.2,
#        38.8, 35.3, 40.6, 40.5, 37.9, 37.2, 40.9, 36.4, 42.2, 37.6, 39.8,
#        36.5, 40.8, 36. , 44.1, 37. , 39.6, 37.5, 42.3, 40.1, 35. , 34.5,
#        41.4, 39. , 35.7, 41.3, 41.6, 35.5, 41.8, 33.5, 39.7, 45.8, 42.8,
#        36.2, 42.1, 42.9, 35.1, 37.3, 36.3, 36.9, 38.3, 34. , 38.1, 33.1,
#        43.2, 41. , 45.6, 42.7, 40.2, 35.2, 41.5, 38.5, 43.1, 36.8, 35.6,
#        32.1, 40.7, 46.5, 50. , 51.3, 45.4, 52.7, 45.2, 46.1, 46.6, 51.7,
#        47. , 52. , 45.9, 50.5, 50.3, 58. , 46.4, 49.2, 42.4, 48.5, 50.6,
#        46.7, 49.5, 52.8, 54.2, 51. , 49.7, 47.5, 47.6, 46.9, 53.5, 49. ,
#        46.2, 50.9, 45.5, 50.8, 50.1, 51.5, 49.8, 48.1, 51.4, 45.7, 50.7,
#        52.2, 49.3, 50.2, 51.9, 46.8, 55.8, 43.5, 49.6, 48.7, 43.3, 48.4,
#        45.1, 46.3, 44.5, 47.8, 48.2, 47.3, 59.6, 49.1, 42.6, 44.4, 44. ,
# ...

# %%
penguins['bill_depth_mm'].unique()
# Out:
# array([18.7, 17.4, 18. ,  nan, 19.3, 20.6, 17.8, 19.6, 18.1, 20.2, 17.1,
#        17.3, 17.6, 21.2, 21.1, 19. , 20.7, 18.4, 21.5, 18.3, 19.2, 17.2,
#        18.9, 18.6, 17.9, 16.7, 17. , 20. , 18.5, 19.1, 19.7, 16.9, 18.8,
#        17.7, 19.5, 17.5, 16.6, 18.2, 16.2, 19.4, 16.8, 16.1, 20.3, 16. ,
#        16.5, 20.5, 19.8, 15.9, 20.1, 15.5, 19.9, 20.8, 16.4, 13.2, 16.3,
#        14.1, 15.2, 14.5, 13.5, 14.6, 15.3, 13.4, 15.4, 13.7, 15.7, 15.1,
#        14.3, 15.8, 13.1, 15. , 14.2, 14.8, 13.6, 13.9, 13.3, 14.4, 13.8,
#        14.9, 15.6, 14. , 14.7])

# %%
penguins['flipper_length_mm'].unique()
# Out:
# array([181., 186., 195.,  nan, 193., 190., 180., 182., 191., 198., 185.,
#        197., 184., 194., 174., 189., 187., 183., 172., 178., 188., 196.,
#        179., 200., 192., 202., 205., 208., 203., 199., 176., 210., 201.,
#        212., 206., 207., 211., 230., 218., 215., 219., 209., 214., 216.,
#        213., 217., 221., 222., 220., 225., 224., 231., 229., 223., 228.,
#        226.])

# %%
penguins['body_mass_g'].unique()
# Out:
# array([3750., 3800., 3250.,   nan, 3450., 3650., 3625., 4675., 3475.,
#        4250., 3300., 3700., 3200., 4400., 4500., 3325., 4200., 3400.,
#        3600., 3950., 3550., 3150., 3900., 4150., 4650., 3100., 3000.,
#        4600., 3425., 2975., 3500., 4300., 4050., 2900., 2850., 3350.,
#        4100., 3050., 4450., 4000., 4700., 4350., 3725., 4725., 3075.,
#        2925., 3175., 4775., 3825., 4275., 4075., 3775., 3875., 3275.,
#        4475., 3975., 3525., 3575., 4550., 3850., 4800., 2700., 3675.,
#        5700., 5400., 5200., 5150., 5550., 5850., 6300., 5350., 5000.,
#        5050., 5100., 5650., 5250., 6050., 4950., 4750., 4900., 5300.,
#        4850., 5800., 6000., 5950., 4625., 5450., 5600., 4875., 4925.,
#        4975., 5500., 4575., 4375., 5750.])

# %%
penguins['sex'].unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
penguins['species'].value_counts()
# Out:
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: species, dtype: int64

# %%
penguins['bill_length_mm'].value_counts()
# Out:
# 41.1    7
# 45.2    6
# 39.6    5
# 37.8    5
# 46.5    5
#        ..
# 45.9    1
# 42.4    1
# 55.1    1
# 52.7    1
# 51.9    1
# Name: bill_length_mm, Length: 164, dtype: int64

# %%
penguins['species'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
penguins['bill_length_mm'].plot(kind='hist', bins = 10)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
penguins['bill_length_mm'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
penguins['bill_depth_mm'].value_counts()
# Out:
# 17.0    12
# 18.6    10
# 15.0    10
# 18.5    10
# 17.9    10
#         ..
# 20.8     1
# 13.4     1
# 17.4     1
# 20.6     1
# 13.3     1
# Name: bill_depth_mm, Length: 80, dtype: int64

# %%
penguins['bill_depth_mm'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
penguins['flipper_length_mm'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
penguins['body_mass_g'].value_counts()
# Out:
# 3800.0    12
# 3700.0    11
# 3950.0    10
# 3900.0    10
# 3550.0     9
#           ..
# 4975.0     1
# 4275.0     1
# 3100.0     1
# 3275.0     1
# 4775.0     1
# Name: body_mass_g, Length: 94, dtype: int64

# %%
penguins['body_mass_g'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
penguins['sex'].value_counts()
# Out:
# Male      168
# Female    165
# Name: sex, dtype: int64

# %%
penguins['sex'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
penguins.plot(kind='bar')
# Out:
# <AxesSubplot:>
