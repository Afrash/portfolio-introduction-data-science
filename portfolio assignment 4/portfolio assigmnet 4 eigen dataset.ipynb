# %%
import pandas as pd

# %%
digimon = pd.read_csv("C:\school jaar 2\blok 3\intro data science\portfolio data science\portfolio-introduction-data-science\DigiDB_digimonlist.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-24801823948d> in <module>()
# ----> 1 digimon = pd.read_csv("C:\school jaar 2\blok 3\intro data science\portfolio data science\portfolio-introduction-data-science\DigiDB_digimonlist.csv")
#
# ...

# %%
pwd

# %%
digimon = pd.read_csv("DigiDB_digimonlist.csv")

# %%
print(digimon)
# Out:
#      Number               Digimon        Stage     Type Attribute  Memory  \
# 0         1               Kuramon         Baby     Free   Neutral       2
# 1         2               Pabumon         Baby     Free   Neutral       2
# 2         3               Punimon         Baby     Free   Neutral       2
# 3         4               Botamon         Baby     Free   Neutral       2
# 4         5               Poyomon         Baby     Free   Neutral       2
# 5         6               Koromon  In-Training     Free      Fire       3
# 6         7               Tanemon  In-Training     Free     Plant       3
# 7         8              Tsunomon  In-Training     Free     Earth       3
# 8         9              Tsumemon  In-Training     Free      Dark       3
# 9        10               Tokomon  In-Training     Free   Neutral       3
# 10       11              Nyaromon  In-Training     Free     Light       3
# 11       12               Pagumon  In-Training     Free      Dark       3
# ...

# %%
print(digimon).head()
# Out:
#      Number               Digimon        Stage     Type Attribute  Memory  \
# 0         1               Kuramon         Baby     Free   Neutral       2
# 1         2               Pabumon         Baby     Free   Neutral       2
# 2         3               Punimon         Baby     Free   Neutral       2
# 3         4               Botamon         Baby     Free   Neutral       2
# 4         5               Poyomon         Baby     Free   Neutral       2
# 5         6               Koromon  In-Training     Free      Fire       3
# 6         7               Tanemon  In-Training     Free     Plant       3
# 7         8              Tsunomon  In-Training     Free     Earth       3
# 8         9              Tsumemon  In-Training     Free      Dark       3
# 9        10               Tokomon  In-Training     Free   Neutral       3
# 10       11              Nyaromon  In-Training     Free     Light       3
# 11       12               Pagumon  In-Training     Free      Dark       3
# ...

# %%
digimon.head()
# Out:
#    Number  Digimon Stage  Type Attribute  Memory  Equip Slots  Lv 50 HP  \
# 0       1  Kuramon  Baby  Free   Neutral       2            0       590
# 1       2  Pabumon  Baby  Free   Neutral       2            0       950
# 2       3  Punimon  Baby  Free   Neutral       2            0       870
# 3       4  Botamon  Baby  Free   Neutral       2            0       690
# 4       5  Poyomon  Baby  Free   Neutral       2            0       540
#
#    Lv50 SP  Lv50 Atk  Lv50 Def  Lv50 Int  Lv50 Spd
# 0       77        79        69        68        95
# 1       62        76        76        69        68
# 2       50        97        87        50        75
# 3       68        77        95        76        61
# 4       98        54        59        95        86
